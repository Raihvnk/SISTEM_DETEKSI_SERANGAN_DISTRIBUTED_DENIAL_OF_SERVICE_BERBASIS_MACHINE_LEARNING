# %%
# Import Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly_express as px
# plt.style.use('default')
color_pallete = ['#fc5185', '#3fc1c9', '#364f6b']
sns.set_palette(color_pallete)
sns.set_style("white")
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import pandas as pd

# Import dataset
dataset = pd.read_csv('train-data.csv')

# Kelompokkan data berdasarkan label
grouped_data = dataset.groupby('label')

# Tampilkan 5 data pertama dari setiap label
for label, label_data in grouped_data:
  print(f"\nLabel: {label}")
  print(label_data.head().to_string(index=False))
# Out:
# Label: DDOS_ICMP
#  datapath_id  version  header_length  tos  total_length  flags  offset  ttl  proto  csum          src_ip   dst_ip  src_port  dst_port  tcp_flag  type_icmp  code_icmp  csum_icmp  port_no  rx_bytes_ave  rx_error_ave  rx_dropped_ave  tx_bytes_ave  tx_error_ave  tx_dropped_ave     label
#            1        4              5    0            28      0       0  250      1 32021 195.233.117.221 10.0.0.4         0         0         0          8        160      62875        1            81             0               0           123             0               0 DDOS_ICMP
#            1        4              5    0            28      0       0  250      1 63527   226.9.220.170 10.0.0.4         0         0         0          8         32      63339        1            78             0               0           123             0               0 DDOS_ICMP
#            1        4              5    0            28      0       0  250      1 45034   60.48.202.193 10.0.0.4         0         0         0          8        236      62781        1            75             0               0           123             0               0 DDOS_ICMP
#            1        4              5    0            28      0       0  250      1 27057   47.121.29.178 10.0.0.4         0         0         0          8        165      63140        1            73             0               0           123             0               0 DDOS_ICMP
#            1        4              5    0            28      0       0  250      1 62701  210.206.239.31 10.0.0.4         0         0         0          8         68      63141        1            71             0               0           123             0               0 DDOS_ICMP
#
# Label: DDOS_TCP
#  datapath_id  version  header_length  tos  total_length  flags  offset  ttl  proto  csum          src_ip   dst_ip  src_port  dst_port  tcp_flag  type_icmp  code_icmp  csum_icmp  port_no  rx_bytes_ave  rx_error_ave  rx_dropped_ave  tx_bytes_ave  tx_error_ave  tx_dropped_ave    label
#            1        4              5    0            40      0       0  250      6 65141     143.7.41.78 10.0.0.4       651        80         2          8        181      63016        1            42             0               0           115             0               0 DDOS_TCP
#            1        4              5    0            40      0       0  250      6 31326  240.128.75.236 10.0.0.4        90        80         2          8        181      63016        1            42             0               0           115             0               0 DDOS_TCP
#            1        4              5    0            40      0       0  250      6 24816 171.107.170.111 10.0.0.4       311        80         2          8        181      63016        1            42             0               0           115             0               0 DDOS_TCP
#            1        4              5    0            40      0       0  250      6   859  58.192.120.176 10.0.0.4       914        80         2          8        181      63016        1            42             0               0           115             0               0 DDOS_TCP
#            1        4              5    0            40      0       0  250      6 45215  46.153.215.146 10.0.0.4       233        80         2          8        181      63016        1            42             0               0           115             0               0 DDOS_TCP
#
# Label: DDOS_UDP
#  datapath_id  version  header_length  tos  total_length  flags  offset  ttl  proto  csum         src_ip   dst_ip  src_port  dst_port  tcp_flag  type_icmp  code_icmp  csum_icmp  port_no  rx_bytes_ave  rx_error_ave  rx_dropped_ave  tx_bytes_ave  tx_error_ave  tx_dropped_ave    label
#            1        4              5    0            55      0       0   64     17  1072    75.80.33.50 10.0.0.4       838       161         2          8        181      63016        1            48             0               0           113             0               0 DDOS_UDP
#            1        4              5    0            55      0       0   64     17 30335  16.53.233.253 10.0.0.4       419       161         2          8        181      63016        1            48             0               0           113             0               0 DDOS_UDP
#            1        4              5    0            55      0       0   64     17 40458  81.24.129.143 10.0.0.4       728       161         2          8        181      63016        1            48             0               0           113             0               0 DDOS_UDP
#            1        4              5    0            55      0       0   64     17 53327 52.136.107.218 10.0.0.4       954       161         2          8        181      63016        1            48             0               0           113             0               0 DDOS_UDP
#            1        4              5    0            55      0       0   64     17 21310    19.37.10.79 10.0.0.4       598       161         2          8        181      63016        1            48             0               0           113             0               0 DDOS_UDP
#
# Label: NORMAL_ICMP
#  datapath_id  version  header_length  tos  total_length  flags  offset  ttl  proto  csum   src_ip   dst_ip  src_port  dst_port  tcp_flag  type_icmp  code_icmp  csum_icmp  port_no  rx_bytes_ave  rx_error_ave  rx_dropped_ave  tx_bytes_ave  tx_error_ave  tx_dropped_ave       label
#            1        4              5    0            28      0       0   64      1 26334 10.0.0.2 10.0.0.1       560       161         2          8          0      63399        1            55             0               0           113             0               0 NORMAL_ICMP
#            1        4              5    0            28      0       0   64      1 26332 10.0.0.4 10.0.0.1       560       161         2          0          0      65437        1            55             0               0           113             0               0 NORMAL_ICMP
#            1        4              5    0            28      0       0   64      1 26334 10.0.0.1 10.0.0.2       560       161         2          8          0      63477        1            55             0               0           113             0               0 NORMAL_ICMP
#            1        4              5    0            28      0       0   64      1 26334 10.0.0.2 10.0.0.1       560       161         2          0          0      65109        1            55             0               0           113             0               0 NORMAL_ICMP
#            1        4              5    0            28      0       0   64      1 26331 10.0.0.4 10.0.0.2       560       161         2          0          0      65025        1            55             0               0           113             0               0 NORMAL_ICMP
#
# Label: NORMAL_TCP
#  datapath_id  version  header_length  tos  total_length  flags  offset  ttl  proto  csum   src_ip   dst_ip  src_port  dst_port  tcp_flag  type_icmp  code_icmp  csum_icmp  port_no  rx_bytes_ave  rx_error_ave  rx_dropped_ave  tx_bytes_ave  tx_error_ave  tx_dropped_ave      label
#            1        4              5    0            40      0       0   64      6 26312 10.0.0.4 10.0.0.4       205        13         0          8          0      63395        1            51             0               0           112             0               0 NORMAL_TCP
#            1        4              5    0            40      0       0   64      6 26316 10.0.0.1 10.0.0.3       848       767         0          8          0      63395        1            51             0               0           112             0               0 NORMAL_TCP
#            1        4              5    0            40      0       0   64      6 26315 10.0.0.4 10.0.0.1       411       930         0          8          0      63395        1            51             0               0           112             0               0 NORMAL_TCP
#            1        4              5    0            40      0       0   64      6 26314 10.0.0.2 10.0.0.4       727       200         0          8          0      63395        1            51             0               0           112             0               0 NORMAL_TCP
#            1        4              5    0            40      0       0   64      6 26315 10.0.0.4 10.0.0.1       987      1016         1          8          0      63395        1            51             0               0           112             0               0 NORMAL_TCP
#
# Label: NORMAL_UDP
#  datapath_id  version  header_length  tos  total_length  flags  offset  ttl  proto  csum   src_ip   dst_ip  src_port  dst_port  tcp_flag  type_icmp  code_icmp  csum_icmp  port_no  rx_bytes_ave  rx_error_ave  rx_dropped_ave  tx_bytes_ave  tx_error_ave  tx_dropped_ave      label
#            1        4              5    0            41      0       0   64     17 26305 10.0.0.2 10.0.0.1       289       912         8          8          0      63395        1            52             0               0           112             0               0 NORMAL_UDP
#            1        4              5    0            41      0       0   64     17 26304 10.0.0.2 10.0.0.2       344       944         8          8          0      63395        1            52             0               0           112             0               0 NORMAL_UDP
#            1        4              5    0            41      0       0   64     17 26304 10.0.0.2 10.0.0.2       913       634         8          8          0      63395        1            52             0               0           112             0               0 NORMAL_UDP
#            1        4              5    0            41      0       0   64     17 26305 10.0.0.1 10.0.0.2       425       210         8          8          0      63395        1            52             0               0           112             0               0 NORMAL_UDP
#            1        4              5    0            41      0       0   64     17 26303 10.0.0.1 10.0.0.4       507       120         8          8          0      63395        1            52             0               0           112             0               0 NORMAL_UDP

# %%
# Check the features
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420000 entries, 0 to 419999
# Data columns (total 26 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   datapath_id     420000 non-null  int64
#  1   version         420000 non-null  int64
#  2   header_length   420000 non-null  int64
#  3   tos             420000 non-null  int64
#  4   total_length    420000 non-null  int64
#  5   flags           420000 non-null  int64
#  6   offset          420000 non-null  int64
#  7   ttl             420000 non-null  int64
#  8   proto           420000 non-null  int64
#  9   csum            420000 non-null  int64
#  10  src_ip          420000 non-null  object
#  11  dst_ip          420000 non-null  object
#  12  src_port        420000 non-null  int64
#  13  dst_port        420000 non-null  int64
#  14  tcp_flag        420000 non-null  int64
#  15  type_icmp       420000 non-null  int64
#  16  code_icmp       420000 non-null  int64
#  17  csum_icmp       420000 non-null  int64
#  18  port_no         420000 non-null  int64
#  19  rx_bytes_ave    420000 non-null  int64
#  20  rx_error_ave    420000 non-null  int64
#  21  rx_dropped_ave  420000 non-null  int64
#  22  tx_bytes_ave    420000 non-null  int64
#  23  tx_error_ave    420000 non-null  int64
#  24  tx_dropped_ave  420000 non-null  int64
#  25  label           420000 non-null  object
# dtypes: int64(23), object(3)
# memory usage: 83.3+ MB

# %%
# menampilkan informasi statistik dataset
dataset.describe()
# Out:
#        datapath_id   version  header_length       tos   total_length  \
# count     420000.0  420000.0       420000.0  420000.0  420000.000000
# mean           1.0       4.0            5.0       0.0      38.666667
# std            0.0       0.0            0.0       0.0       9.159099
# min            1.0       4.0            5.0       0.0      28.000000
# 25%            1.0       4.0            5.0       0.0      28.000000
# 50%            1.0       4.0            5.0       0.0      40.000000
# 75%            1.0       4.0            5.0       0.0      41.000000
# max            1.0       4.0            5.0       0.0      55.000000
#
#           flags    offset            ttl          proto           csum  ...  \
# count  420000.0  420000.0  420000.000000  420000.000000  420000.000000  ...
# mean        0.0       0.0     126.000000       8.000000   29582.624348  ...
# std         0.0       0.0      87.681345       6.683321   13770.511591  ...
# min         0.0       0.0      64.000000       1.000000       0.000000  ...
# 25%         0.0       0.0      64.000000       1.000000   26302.000000  ...
# 50%         0.0       0.0      64.000000       6.000000   26316.000000  ...
# 75%         0.0       0.0     250.000000      17.000000   32833.000000  ...
# max         0.0       0.0     250.000000      17.000000   65534.000000  ...
#
#            type_icmp      code_icmp      csum_icmp   port_no   rx_bytes_ave  \
# count  420000.000000  420000.000000  420000.000000  420000.0  420000.000000
# mean        7.333257      81.643438   63363.863471       1.0      49.141890
# std         2.211201      88.830461     606.359741       0.0       4.209329
# min         0.000000       0.000000   62722.000000       1.0      42.000000
# 25%         8.000000       0.000000   63016.000000       1.0      46.000000
# 50%         8.000000       0.000000   63233.000000       1.0      51.000000
# 75%         8.000000     181.000000   63395.000000       1.0      52.000000
# max         8.000000     255.000000   65535.000000       1.0      81.000000
#
#        rx_error_ave  rx_dropped_ave   tx_bytes_ave  tx_error_ave  \
# count      420000.0        420000.0  420000.000000      420000.0
# mean            0.0             0.0     113.278310           0.0
# std             0.0             0.0       1.942621           0.0
# min             0.0             0.0     111.000000           0.0
# 25%             0.0             0.0     112.000000           0.0
# 50%             0.0             0.0     113.000000           0.0
# 75%             0.0             0.0     114.000000           0.0
# max             0.0             0.0     123.000000           0.0
#
#        tx_dropped_ave
# count        420000.0
# mean              0.0
# std               0.0
# min               0.0
# 25%               0.0
# 50%               0.0
# 75%               0.0
# max               0.0
#
# [8 rows x 23 columns]

# %%
#drop column dikarenakan data setiap fitur tidak mengelompok atau tersebar jauh dari pusat kelompok (mean).
columns_to_drop = ['tos', 'flags', 'offset', 'code_icmp', 'rx_error_ave', 'rx_dropped_ave', 'tx_error_ave', 'tx_dropped_ave']
dataset = dataset.drop(columns=columns_to_drop)

# %%
#drop column dikarenakan bertipe object
columns_to_drop = ['src_ip', 'dst_ip']
dataset = dataset.drop(columns=columns_to_drop)

# %%
# Check the dataset if there's NaN value
print(dataset.isna().values.any())
# Out:
# False

# %%
# Get unique categories from the 'label' column
unique_categories = dataset['label'].unique()

# Print the unique categories
print(unique_categories)
# Out:
# ['DDOS_ICMP' 'DDOS_TCP' 'DDOS_UDP' 'NORMAL_ICMP' 'NORMAL_TCP' 'NORMAL_UDP']

# %%
# Mengganti kolom label string
iris = dataset.replace(
{"label": {"DDOS_ICMP": 1, "DDOS_TCP": 2, "DDOS_UDP": 3, "NORMAL_ICMP": 4, "NORMAL_TCP": 5, "NORMAL_UDP": 6}})
# menampilkan heatmap (correlation matrix)
plt.figure(figsize=(8, 6))  
sns.heatmap(iris.corr(numeric_only=True), annot=True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.title("Correlation on DDOS attack label")
plt.tight_layout()
plt.show()

# %%
# Calculate the correlation matrix directly
correlation_matrix = iris.corr()

# Convert correlation matrix to a flat Series
corr_values = correlation_matrix.stack()

# Sort by absolute correlation (descending order)
sorted_corr = corr_values.abs().sort_values(ascending=False)

# Print the most correlated features
print("From top to the least Correlated Features:")
for feature, correlation in sorted_corr[:50].items():
    print(f"{feature}: {correlation:.3f}")
# Out:
# From top to the least Correlated Features:
# ('total_length', 'total_length'): 1.000
# ('ttl', 'ttl'): 1.000
# ('tx_bytes_ave', 'tx_bytes_ave'): 1.000
# ('rx_bytes_ave', 'rx_bytes_ave'): 1.000
# ('csum_icmp', 'csum_icmp'): 1.000
# ('type_icmp', 'type_icmp'): 1.000
# ('tcp_flag', 'tcp_flag'): 1.000
# ('dst_port', 'dst_port'): 1.000
# ('src_port', 'src_port'): 1.000
# ('csum', 'csum'): 1.000
# ('proto', 'proto'): 1.000
# ('label', 'label'): 1.000
# ('type_icmp', 'csum_icmp'): 0.953
# ('csum_icmp', 'type_icmp'): 0.953
# ('rx_bytes_ave', 'ttl'): 0.932
# ('ttl', 'rx_bytes_ave'): 0.932
# ('total_length', 'proto'): 0.849
# ('proto', 'total_length'): 0.849
# ('label', 'ttl'): 0.828
# ('ttl', 'label'): 0.828
# ('rx_bytes_ave', 'label'): 0.813
# ('label', 'rx_bytes_ave'): 0.813
# ('tx_bytes_ave', 'rx_bytes_ave'): 0.809
# ('rx_bytes_ave', 'tx_bytes_ave'): 0.809
# ('tx_bytes_ave', 'label'): 0.784
# ('label', 'tx_bytes_ave'): 0.784
# ('tx_bytes_ave', 'ttl'): 0.744
# ('ttl', 'tx_bytes_ave'): 0.744
# ('dst_port', 'label'): 0.713
# ('label', 'dst_port'): 0.713
# ('label', 'tcp_flag'): 0.531
# ('tcp_flag', 'label'): 0.531
# ('dst_port', 'ttl'): 0.529
# ('ttl', 'dst_port'): 0.529
# ('tx_bytes_ave', 'dst_port'): 0.514
# ('dst_port', 'tx_bytes_ave'): 0.514
# ('tx_bytes_ave', 'src_port'): 0.505
# ('src_port', 'tx_bytes_ave'): 0.505
# ('dst_port', 'rx_bytes_ave'): 0.495
# ('rx_bytes_ave', 'dst_port'): 0.495
# ('src_port', 'rx_bytes_ave'): 0.488
# ('rx_bytes_ave', 'src_port'): 0.488
# ('proto', 'ttl'): 0.476
# ('ttl', 'proto'): 0.476
# ('proto', 'label'): 0.467
# ('label', 'proto'): 0.467
# ('rx_bytes_ave', 'proto'): 0.443
# ('proto', 'rx_bytes_ave'): 0.443
# ('dst_port', 'tcp_flag'): 0.439
# ('tcp_flag', 'dst_port'): 0.439

# %%
# Pilih kolom 
kolom= ['type_icmp', 'csum_icmp', 'rx_bytes_ave', 'ttl','label']

# Buat matriks plotting
plt.figure(figsize=(8, 8))
ax = sns.pairplot(dataset[kolom], hue='label')

# Tampilkan plot
plt.show()

# %%
# Save preprocessed data to a CSV file
dataset.to_csv('preprocessed_train_datasets.csv', index=False)
print("Preprocessed data saved to preprocessed_train_datasets.csv")
# Out:
# Preprocessed data saved to preprocessed_train_datasets.csv
